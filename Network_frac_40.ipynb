# %%
# neural network that takes in four design variables from composites and outputs a predicted failure load

# ----------------------------------------------------
# INPUT
# [fiber type, fiber weight, dispersing agent, mixing]
# ----------------------------------------------------
# # fiber type
# ## 0 = PR
# ## 1 = OX
# ----------------------------------------------------
# # fiber weight
# ## .25 -> 1.00 in .25 increments
# ----------------------------------------------------
# # dispersing agent
# ## 0 = no
# ## 1 = yes
# ----------------------------------------------------
# # mixing
# ## 0 = SO
# ## 1 = HS
# ## 2 = HS + SO
# ----------------------------------------------------

# %%
# IMPORTS 
import tensorflow as tf
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt

# %%
# Bring in data
df = pd.read_excel('Flex_Data.xlsx', usecols='B:E,K', skiprows=3)

# one-hotify the data that is not numerical
df['Fiber\nType'] = df['Fiber\nType'].map({'PR':0, 'OX':1})
df['Dispersing\nAgent'] = df['Dispersing\nAgent'].map({'No':0, 'Yes':1})
df['Mixing'] = df['Mixing'].map({'SO':0, 'HS':1, 'SO+HS':2})

# rename the failure load column
df.rename(columns={'Unnamed: 10':'Failure Load'}, inplace = True)

# create a train and test set from the data
train_df = df[df.index % 2 == 0]
train_df = train_df.append(df[df.index % 10 == 1])
train_df = train_df.sample(frac=1)
test_df = df.drop(train_df.index)

# create data set of the experimentally found Failure Load
train_labels = train_df.pop('Failure Load')
test_labels = test_df.pop('Failure Load')

# convert the pandas dataframes to numpy arrays
train_dataset = train_df.to_numpy()
train_labels = train_labels.to_numpy() / 1451.933

test_dataset = test_df.to_numpy()
test_labels = test_labels.to_numpy() /1451.933

# %%
# Build model

model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='tanh', input_shape=[4,]),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(64, activation='tanh'),
    tf.keras.layers.Dense(1)
])

# optimizer chosen for fitting the data
optimizer = tf.keras.optimizers.RMSprop(.001)
# optimizer = tf.keras.optimizers.Adam()

# compile the model and print a summary of the model
model.compile(loss='mse',
              optimizer=optimizer,
              metrics=['mae', 'mse'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                320
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 21,121
# Trainable params: 21,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# define the epochs and train the model
EPOCHS = 10000

history = model.fit(
  train_dataset, train_labels,
  epochs=EPOCHS, validation_split=0.1,
  verbose=0)

# %%
# test the model on the test data that was set aside
test_predict = model.predict(test_dataset)

predicted = []
actual = []

with open('testDataRaw/frac_40_res.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['ANN prediction'])
    writer.writerow(['variables', 'actual', 'predicted'])

    for sample in range(len(test_labels)):
        
        actual.append(test_labels[sample])
        predicted.append(test_predict[sample])
        
        print(f"Test set actual: {test_labels[sample]}, Predicted: {test_predict[sample]}")
        writer.writerow([test_dataset[sample], test_labels[sample], test_predict[sample][0]])
# Out:
# Test set actual: 0.477423545025838, Predicted: [0.46978128]
# Test set actual: 0.565347023588554, Predicted: [0.36037326]
# Test set actual: 0.406802517747031, Predicted: [0.26828104]
# Test set actual: 0.25797609118327086, Predicted: [0.35015208]
# Test set actual: 0.3135681880637743, Predicted: [0.3789792]
# Test set actual: 0.3467501599591717, Predicted: [0.29156744]
# Test set actual: 0.20457762169466498, Predicted: [0.16304132]
# Test set actual: 0.2004080078075228, Predicted: [0.3803861]
# Test set actual: 0.6235198180632302, Predicted: [0.4620368]
# Test set actual: 0.2853988441615419, Predicted: [0.16843757]
# Test set actual: 0.4666985322325479, Predicted: [0.3824817]
# Test set actual: 0.5325383471551374, Predicted: [0.31623703]
# Test set actual: 0.5961817797377703, Predicted: [0.5754834]
# Test set actual: 0.25134217625744437, Predicted: [0.4974143]
# Test set actual: 0.6644369953709985, Predicted: [0.63611585]
# Test set actual: 0.517026612109512, Predicted: [0.509505]
# Test set actual: 0.5325493669473729, Predicted: [0.7209113]
# Test set actual: 0.3265873838531117, Predicted: [0.7426468]
# Test set actual: 0.2986074426299285, Predicted: [0.58410233]
# Test set actual: 0.2854215724830278, Predicted: [0.47094274]
# Test set actual: 0.60872023709083, Predicted: [0.25332823]
# Test set actual: 0.49643888526536695, Predicted: [0.51641536]
# Test set actual: 0.47611976585696447, Predicted: [0.49077237]
# Test set actual: 0.6254441492823705, Predicted: [0.5562562]
# Test set actual: 0.5491506839502925, Predicted: [0.5967156]
# Test set actual: 0.6797324669940005, Predicted: [1.0013348]
# Test set actual: 0.5846406135820317, Predicted: [0.3267973]
# Test set actual: 0.690186117403489, Predicted: [0.49618584]
# Test set actual: 0.5375854119990385, Predicted: [0.7092399]
# Test set actual: 0.5908020549157571, Predicted: [0.2659419]
# Test set actual: 0.6868705374146052, Predicted: [0.5971335]
# Test set actual: 0.4561677432774102, Predicted: [0.5788316]
# Test set actual: 0.4479697065911444, Predicted: [0.47360617]
# Test set actual: 0.32434967729227177, Predicted: [0.27821308]
# Test set actual: 0.445373168045633, Predicted: [0.6296038]
# Test set actual: 0.5492705241908545, Predicted: [0.49984574]
# Test set actual: 0.4564384169241969, Predicted: [0.5014374]
# Test set actual: 0.46280647936233976, Predicted: [0.50819]

# %%
plt.figure(figsize=(10,10))

# 100% confidence
x = np.linspace(0,1,100)
y1 = x

plt.plot(x, y1, 'k-')

# 80% confidence interval
y2 = x + .1
y3 = x - .1

plt.fill_between(x, y1, y2,facecolor='grey')
plt.fill_between(x, y1, y3, facecolor='grey')

# 60% confidence interval
y4 = x + .2
y5 = x - .2

plt.fill_between(x, y2, y4, facecolor='silver')
plt.fill_between(x, y3, y5,facecolor='silver')

# 40% confidence interval
y6 = x + .3
y7 = x - .3

plt.fill_between(x, y4, y6, facecolor='gainsboro')
plt.fill_between(x, y5, y7, facecolor='gainsboro')

# plot results of NN
plt.plot(actual, predicted, 'ko')

plt.axis([0, 1, 0, 1])
plt.ylabel('Predicted')
plt.xlabel('Experimental')

plt.savefig('testDataPlots/frac_40_plot.png')
# plt.show()

# %%
# THIC FOR LOOP TO GO THROUGH ALL SYNTHETIC DATA
for num in range(1, 13):
    # PREDICT SYNTHETIC DATA
    synth = pd.read_csv(f"synthData/{num}.csv")
    
    synth_arr = synth.to_numpy()
    
    synth_res = model.predict(synth_arr)
    
    # WRITE TO CSV
    with open(f'res/res_40/failureLoad/rawData/set-{num}.csv', 'w', newline='') as file:
        w = csv.writer(file)
        w.writerow(['Fiber Weight', 'Failure Load'])
        for row in range(len(synth_res)):
            w.writerow([synth_arr[row][1], synth_res[row][0] * 1451.933])
    
    # PLOT THE FAILURE LOAD
    plt.figure(figsize=(10,10))
    plt.xlim(0, 1)
    plt.ylim(0, 1500)
    
    # TITLE STUFF
    fiberType = "PR" if synth_arr[0][0] == 0 else "OX"
    dispAgent = "No" if synth_arr[0][2] == 0 else "Yes"
    mix = synth_arr[0][3]
    if mix == 0:
        mix = "SO"
    if mix == 1:
        mix = "HS"
    if mix == 2:
        mix = "SO+HS"
    plt.title(f"Synthetic Set %s Results for Failure Load (FT=%s, DS=%s, Mix=%s)" % (num, fiberType, dispAgent, mix))
    
    plt.ylabel('Failure Load')
    plt.xlabel('Fiber Weight')
    
    plt.plot(synth['Fiber Weight'], synth_res * 1451.933, 'k')
    
    plt.savefig("res/res_40/failureLoad/plots/set-%s.png" % num)
