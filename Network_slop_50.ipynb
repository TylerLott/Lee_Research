# %%
# neural network that takes in four design variables from composites and outputs a predicted failure load

# ----------------------------------------------------
# INPUT
# [fiber type, fiber weight, dispersing agent, mixing]
# ----------------------------------------------------
# # fiber type
# ## 0 = PR
# ## 1 = OX
# ----------------------------------------------------
# # fiber weight
# ## .25 -> 1.00 in .25 increments
# ----------------------------------------------------
# # dispersing agent
# ## 0 = no
# ## 1 = yes
# ----------------------------------------------------
# # mixing
# ## 0 = SO
# ## 1 = HS
# ## 2 = HS + SO
# ----------------------------------------------------

# %%
# IMPORTS 
import tensorflow as tf
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt

# %%
# Bring in data
df = pd.read_excel('Flex_Data.xlsx', usecols='B:E,G', skiprows=3)

print(df)

# one-hotify the data that is not numerical
df['Fiber\nType'] = df['Fiber\nType'].map({'PR':0, 'OX':1})
df['Dispersing\nAgent'] = df['Dispersing\nAgent'].map({'No':0, 'Yes':1})
df['Mixing'] = df['Mixing'].map({'SO':0, 'HS':1, 'SO+HS':2})

# rename the failure load column
df.rename(columns={'Unnamed: 6':'Initial Slope'}, inplace = True)

# create a train and test set from the data
train_df = df[df.index % 2 == 0]
train_df = train_df.sample(frac=1)
test_df = df.drop(train_df.index)

# create data set of the experimentally found Failure Load
train_labels = train_df.pop('Initial Slope')
test_labels = test_df.pop('Initial Slope')

# convert the pandas dataframes to numpy arrays
train_dataset = train_df.to_numpy()
train_labels = train_labels.to_numpy() / 463.6

test_dataset = test_df.to_numpy()
test_labels = test_labels.to_numpy() / 463.6
# Out:
#    Fiber\nType  Fiber\nWeight (phr) Dispersing\nAgent Mixing  Unnamed: 6
# 0           PR                 0.25                No     SO       323.9
# 1           PR                 0.25                No     SO       266.9
# 2           PR                 0.50                No     SO       231.2
# 3           PR                 0.50                No     SO       267.8
# 4           PR                 0.75                No     SO       342.5
# ..         ...                  ...               ...    ...         ...
# 91          OX                 0.50               Yes  SO+HS       306.9
# 92          OX                 0.75               Yes  SO+HS       253.6
# 93          OX                 0.75               Yes  SO+HS       333.6
# 94          OX                 1.00               Yes  SO+HS       206.2
# 95          OX                 1.00               Yes  SO+HS       173.4
#
# [96 rows x 5 columns]

# %%
# Build model

model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='tanh', input_shape=[4,]),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(64, activation='tanh'),
    tf.keras.layers.Dense(1)
])

# optimizer chosen for fitting the data
optimizer = tf.keras.optimizers.RMSprop(.001)
# optimizer = tf.keras.optimizers.Adam()

# compile the model and print a summary of the model
model.compile(loss='mse',
              optimizer=optimizer,
              metrics=['mae', 'mse'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                320
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 21,121
# Trainable params: 21,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# define the epochs and train the model
EPOCHS = 10000

history = model.fit(
  train_dataset, train_labels,
  epochs=EPOCHS, validation_split=0.1,
  verbose=0)

# %%
# test the model on the test data that was set aside
test_predict = model.predict(test_dataset)

predicted = []
actual = []

with open('testDataRaw/slop_50_res.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['ANN prediction'])
    writer.writerow(['variables', 'actual', 'predicted'])

    for sample in range(len(test_labels)):
        
        actual.append(test_labels[sample])
        predicted.append(test_predict[sample])
        
        print(f"Test set actual: {test_labels[sample]}, Predicted: {test_predict[sample]}")
        writer.writerow([test_dataset[sample], test_labels[sample], test_predict[sample][0]])
# Out:
# Test set actual: 0.5757118205349439, Predicted: [0.70008874]
# Test set actual: 0.5776531492666092, Predicted: [0.4970432]
# Test set actual: 0.6902502157031923, Predicted: [0.7504449]
# Test set actual: 0.6518550474547022, Predicted: [0.6393508]
# Test set actual: 0.6266177739430543, Predicted: [0.7371641]
# Test set actual: 0.9419758412424503, Predicted: [0.80611163]
# Test set actual: 0.8503019844693701, Predicted: [0.84411275]
# Test set actual: 0.850086281276963, Predicted: [0.87630886]
# Test set actual: 0.294434857635893, Predicted: [0.4042535]
# Test set actual: 0.5981449525452976, Predicted: [0.48804304]
# Test set actual: 0.6175582398619499, Predicted: [0.6154547]
# Test set actual: 0.611518550474547, Predicted: [0.5044544]
# Test set actual: 0.8022001725625538, Predicted: [0.42460424]
# Test set actual: 0.7437446074201898, Predicted: [0.74118924]
# Test set actual: 0.5179033649698015, Predicted: [0.641796]
# Test set actual: 0.6479723899913717, Predicted: [0.7687038]
# Test set actual: 0.5448662640207075, Predicted: [0.657688]
# Test set actual: 0.4091889559965487, Predicted: [0.61079895]
# Test set actual: 0.8828731665228645, Predicted: [0.8477889]
# Test set actual: 0.7400776531492667, Predicted: [0.70667225]
# Test set actual: 0.8470664365832614, Predicted: [0.70929074]
# Test set actual: 0.833692838654012, Predicted: [0.9056956]
# Test set actual: 0.6179896462467644, Predicted: [0.93164337]
# Test set actual: 0.8375754961173425, Predicted: [0.80181926]
# Test set actual: 0.29723899913718727, Predicted: [0.4061721]
# Test set actual: 0.7040552200172562, Predicted: [0.7022574]
# Test set actual: 0.6417169974115616, Predicted: [0.592096]
# Test set actual: 0.5310612597066436, Predicted: [0.57285094]
# Test set actual: 0.6475409836065573, Predicted: [0.46254107]
# Test set actual: 0.7133304572907678, Predicted: [0.4398055]
# Test set actual: 0.66458153580673, Predicted: [0.7454637]
# Test set actual: 0.7014667817083692, Predicted: [0.7166865]
# Test set actual: 0.6175582398619499, Predicted: [1.024046]
# Test set actual: 0.8462036238136325, Predicted: [0.33690265]
# Test set actual: 0.7176445211389127, Predicted: [0.5958698]
# Test set actual: 0.8474978429680758, Predicted: [0.71420866]
# Test set actual: 0.8086712683347713, Predicted: [0.8788184]
# Test set actual: 0.7709232096635029, Predicted: [0.68372416]
# Test set actual: 0.921699741156169, Predicted: [0.9023073]
# Test set actual: 0.8330457290767903, Predicted: [0.5618359]
# Test set actual: 0.7128990509059534, Predicted: [0.7114644]
# Test set actual: 0.4201898188093184, Predicted: [0.62156606]
# Test set actual: 0.5886540120793787, Predicted: [0.45633543]
# Test set actual: 0.6667385677308024, Predicted: [0.5975745]
# Test set actual: 0.8677739430543572, Predicted: [0.62412715]
# Test set actual: 0.6619930974978429, Predicted: [0.7217337]
# Test set actual: 0.719585849870578, Predicted: [0.5528035]
# Test set actual: 0.3740293356341674, Predicted: [0.4525736]

# %%
plt.figure(figsize=(10,10))

# 100% confidence
x = np.linspace(0,1,100)
y1 = x

plt.plot(x, y1, 'k-')

# 80% confidence interval
y2 = x + .1
y3 = x - .1

plt.fill_between(x, y1, y2,facecolor='grey')
plt.fill_between(x, y1, y3, facecolor='grey')

# 60% confidence interval
y4 = x + .2
y5 = x - .2

plt.fill_between(x, y2, y4, facecolor='silver')
plt.fill_between(x, y3, y5,facecolor='silver')

# 40% confidence interval
y6 = x + .3
y7 = x - .3

plt.fill_between(x, y4, y6, facecolor='gainsboro')
plt.fill_between(x, y5, y7, facecolor='gainsboro')

# plot results of NN
plt.plot(actual, predicted, 'ko')

plt.axis([0, 1, 0, 1])
plt.ylabel('Predicted')
plt.xlabel('Experimental')

plt.savefig('testDataPlots/slop_50_plot.png')
# plt.show()

# %%
# THIC FOR LOOP TO GO THROUGH ALL SYNTHETIC DATA
for num in range(1, 13):
    # PREDICT SYNTHETIC DATA
    synth = pd.read_csv(f"synthData/{num}.csv")
    
    synth_arr = synth.to_numpy()
    
    synth_res = model.predict(synth_arr)
    
    # WRITE TO CSV
    with open(f'res/res_50/iniSlope/rawData/set-{num}.csv', 'w', newline='') as file:
        w = csv.writer(file)
        w.writerow(['Fiber Weight', 'Initial Slope'])
        for row in range(len(synth_res)):
            w.writerow([synth_arr[row][1], synth_res[row][0] * 463.6])
    
    # PLOT THE FAILURE LOAD
    plt.figure(figsize=(10,10))
    plt.xlim(0, 1)
    plt.ylim(0, 500)
    
    # TITLE STUFF
    fiberType = "PR" if synth_arr[0][0] == 0 else "OX"
    dispAgent = "No" if synth_arr[0][2] == 0 else "Yes"
    mix = synth_arr[0][3]
    if mix == 0:
        mix = "SO"
    if mix == 1:
        mix = "HS"
    if mix == 2:
        mix = "SO+HS"
    plt.title(f"Synthetic Set %s Results for Initial Slope (FT=%s, DS=%s, Mix=%s)" % (num, fiberType, dispAgent, mix))
    
    plt.ylabel('Initial Slope')
    plt.xlabel('Fiber Weight')
    
    plt.plot(synth['Fiber Weight'], synth_res * 463.6, 'k')
    
    plt.savefig("res/res_50/iniSlope/plots/set-%s.png" % num)
